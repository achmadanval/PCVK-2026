# %% [markdown]
# <a href="https://colab.research.google.com/github/achmadanval/PCVK-2026/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Langkah 1**

# %% [markdown]
# 1. Mampu membuat repository di Github
# 2. Mampu membuat Phyton Notebook di Google Colaborator
# 3. Mampu menyimpan dan mengakses Phyton Notebook dari Google Colaborator
# 4. Mampu membuka file Citra dari Code Phyton
# 5. Mampu mengakses Pixelpada citra

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# ### Langakh 2
#
# Baca imgae dari URLs - Read image From URls
#
# Pada langkah ini kita akan emmbaca image dari URLs, menampilkanya menggunakan OpenCV, Perhatikan ada perbedaan ketika membuka imgae dalam RGB dan BGR, Channel warna default untuk OpenCV dalah BGR.

# %%
# Membuat List untuk menyimpan URL dari beberapa imgae
imageurls =[
    "https://raw.githubusercontent.com/opencv/opencv/master/samples/data/fruits.jpg",
    "https://raw.githubusercontent.com/opencv/opencv/master/samples/data/butterfly.jpg",
    "https://raw.githubusercontent.com/opencv/opencv/master/samples/data/starry_night.jpg",
]# Baca dan tampilkan image
# loop pada tiap url image, bebrapa image dapat disimpan pada list

for url in imageurls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = np.concatenate((image, image_2))
  cv2_imshow(final_frame)
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=256x480>
# <PIL.Image.Image image mode=RGB size=246x356>
# <PIL.Image.Image image mode=RGB size=376x600>

# %% [markdown]
# ### Langkah 3

# %% [markdown]
# Melihat ukuran resolusi File image - Preview File image resolution

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("Resolusi image: Tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# Resolusi image: Tinggi x lebar =  300  x  376
# <PIL.Image.Image image mode=RGB size=376x300>

# %%
image_3 = image.copy()

row = int(image_3.shape[0] / 2)

#garis horizontal di tengah image tanpa loop
#image_3[int(image.shape[0]/2),:]=[0,255,0]

#membuat garis horizontal ditengah image dengan loop

for x in range(image_3.shape[1]):
  image_3[row, x] = [0, 255, 0]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=752x300>

# %% [markdown]
# ### Pertanyaan Praktikum D2
#
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke
# delapan? Apakah semua library tersebut harus digunakan dalam praktikum
# sesi ini?
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
# image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
# Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak
# dilakukan
# 4. Perhatikan potongan kode progam berikut :
# Apakah kegunaan kode [0, 255, 0] ? Jelaskan!
# 5.  Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun
# rendah!

# %% [markdown]
# ### Jawaban
# 1. Karena dengan menggunakan google colab, kita tidak perlu rumit melakukan instalasi pyhton beserta librarynya pada perangkat masing masing yang membuat komputer jadi berat, serta mempermudah dalam pengumpulan tugas dan bisa melakukan colaborasi dengan mudah
# 2. Numpy - Representasi Citra sebagai Matrix karena dalam python gambar digital dibaca sebagai array multidimensi.
#
#     Pandas - DIguakan untuk mengelola informasi terkait berkas gambar seperti path, dimensi, ukuran file, atau label kelas.
#
#     OpenCV - berfungsi untuk membaca file gambar, memfilter,deteksi tepi, serta ekstraksi kontur.berfungsi untuk memanipulasi warna dan untuk pengenalan objek secara real-time.
#
#     Skimage - befungsi untuk anallisis citra dengan implementasi algoritma yang rapi. seperti melakukan segmentasi, restorasi citra,  dan morfologi visual.
#
#     PIL - Library ini digunakan untuk membuka, menyimpan, dan mengubah format berkas gambar.serta bisa digunakan untuk resize, pembuatan thumbnail dan penambahan teks watermark langsung ke citra.
#
#     Matplotlib - digunakan untuk menampilkan gambar secara visual dalam antarmuka notebook lengkap dengan skala koordinat piksel.
#
#     semua library tersebut digunakan pada praktikum ini karena digunakan untuk melakukan perubahan pada sebuah gambar.
#
# 3. digunakan untuk melakukan pengecilan ukuran gambar jika kode tersebut tidak dijalankan akan menampilkan gambar dengan ukuran aslinya yang membuat pemrosesan gambar menjadi sedikit lebih lama.
# 4. Kode tersbut digunakan untuk menampilkan warna yang ingin di tampilkan jika menggunakan Format BGR kode tersebut akan menampilkan warna hijau. jika kodenya digant menjadi [255, 0, 0] garis terbut akan menampilkan warna biru.
# 5. pixel merupakan unit terkecil pembentuk citra digital yang menyimpan nilai intensitas warna, sedangkan resolusi merupakan kerapatan atau jumlah total pixel yang menyusun gambar tersebut.
# semakin tinggi resolusi sebuah gambar semakin banyak juga jumlah pixel di dalamnya.

# %% [markdown]
# ### Tugas Praktikum D2

# %% [markdown]
# 2. Buat garis vertikal dan garis menyilang diagonal pada image keluaran

# %%
image_3 = image.copy()
height, width, channels = image_3.shape

x = width // 2
image_3[0:height, x] = [0, 255, 0]
cv2_imshow(image_3)
# Out:
# <PIL.Image.Image image mode=RGB size=376x300>

# %% [markdown]
# 3. Menambahkan Garis Diagonal

# %%
image_3 = image.copy()
cv.line(image_3, (0,0), (width -1, height - 1), (0, 255, 0), 1)
cv.line(image_3, (width - 1, 0),(0, height -1 ), (0, 255, 0), 1)
cv2_imshow(image_3)
# Out:
# <PIL.Image.Image image mode=RGB size=376x300>

# %% [markdown]
# 3.  Buat garis horizontal berwarna merah dibagian tengah gambar dengan
# panjang tertentu

# %%
image_2 = image.copy()
image_2 = cv.cvtColor(image, cv.COLOR_BGRA2RGB)
y = height // 2
x = width // 2
image_2[y, x - 50 : x + 100] = [0, 0,255]

cv2_imshow(image_2)
# Out:
# <PIL.Image.Image image mode=RGB size=376x300>

# %% [markdown]
# 4. Buat kotak menggunakan kumpulan pixel warna putih di sembarang tempat
# dalam gambar

# %%
image_2 = image.copy()
image_2 = cv.cvtColor(image, cv.COLOR_BGRA2RGB)

r1, c1 = 100, 150
r2, c2 = 200, 250

image_2[r1:r2, c1:c2] = [255, 255, 255]

cv2_imshow(image_2)
# Out:
# <PIL.Image.Image image mode=RGB size=376x300>
